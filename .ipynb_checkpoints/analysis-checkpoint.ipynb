# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
to_cmplx ={'A':1j,'C':-1,'G':1, 'R':1j, 'M': 1j, 'K':1, 'S':-1,
           'T':-1j, 'Y':-1, 'R':1j, 'W':1j, 'N':1j} #Y->C, T or U; R->A or G; W-> A, T or U;
                                                    #N->A C G T U; R-> A or G; M->A or C; K-> G, T or U
                                                    #S->C or G

def s2cmlx(s):
    return np.array([to_cmplx[c] for c in s])

# %%
f = open('./sequence.fasta','r')
virus_names = []
virus_dict = {}
new_genome = False
virus_genome = ""
virus_name = ""

for l in f.readlines():
    if l.startswith('\n'):
        new_genome = False
        virus_dict[virus_name]=s2cmlx(virus_genome)
        #print(f"END{virus_name}")
    if l.startswith('>'):
        new_genome = True
        virus_name = l[1:-1]
        virus_names.append(virus_name)
        virus_genome = ""
        #print(f"START{virus_name}")
    if (l.startswith('A')) or (l.startswith('T')) or (l.startswith('G')) or (l.startswith('C')):
        virus_genome = virus_genome + l[0:-1]
    

f.close()

# %% [markdown]
# ## Simple Plot

# %%
c = np.correlate(virus_dict['NC_045512.2 Severe acute respiratory syndrome coronavirus 2 isolate Wuhan-Hu-1, complete genome'],
             virus_dict['NC_001802.1 Human immunodeficiency virus 1, complete genome'], "full")

# %%
fig, ax = plt.subplots(figsize=(12, 12))
ax.plot(np.real(c))
plt.plot()
# Out:
# []

# %% [markdown]
# ## Simple similarity analysis

# %%
similarity_dict={}
for v,g in virus_dict.items():
    if v!='NC_045512.2 Severe acute respiratory syndrome coronavirus 2 isolate Wuhan-Hu-1, complete genome':
        xcorr = np.correlate(virus_dict['NC_045512.2 Severe acute respiratory syndrome coronavirus 2 isolate Wuhan-Hu-1, complete genome'],
             virus_dict[v], "full")
        similarity_dict[v]=[np.mean(np.real(xcorr)), np.max(np.real(xcorr)), len(np.real(xcorr))]
        #print(f'{v} mean: {np.mean(np.absolute(xcorr))}, max: {np.max(np.absolute(xcorr))}, size: {len(np.absolute(xcorr))}')

# %%
similarity_df = pd.DataFrame(similarity_dict).transpose()
similarity_df.columns=['Crosscorrelation Mean','Crosscorrelation Max','Crosscorrelation Vector size']

# %%
similarity_df.sort_values('Crosscorrelation Max',ascending=False).head(50)
# Out:
#                                                     Crosscorrelation Mean  \
# NC_004718.3 SARS coronavirus, complete genome                    8.638576
# NC_038294.1 Betacoronavirus England 1, complete...              21.733908
# NC_019843.3 Middle East respiratory syndrome co...              21.410973
# NC_003045.1 Bovine coronavirus, complete genome                 38.896521
# NC_006577.2 Human coronavirus HKU1, complete ge...              50.446012
# NC_001451.1 Avian infectious bronchitis virus, ...              23.143349
# NC_006213.1 Human coronavirus OC43 strain ATCC ...              37.792309
# NC_002645.1 Human coronavirus 229E, complete ge...              31.428966
# NC_005831.2 Human Coronavirus NL63, complete ge...              49.491028
# NC_028752.1 Camel alphacoronavirus isolate came...              31.435398
# NC_010800.1 Turkey coronavirus, complete genome                 22.663406
# NC_007447.1 Breda virus, complete genome                        33.649280
# NC_007605.1 Human gammaherpesvirus 4, complete ...               5.367818
# NC_027016.1 Papio ursinus cytomegalovirus isola...              -0.167025
# NC_006273.2 Human herpesvirus 5 strain Merlin, ...              -0.582294
# NC_009334.1 Human herpesvirus 4, complete genome                 5.204139
# NC_001664.4 Human betaherpesvirus 6A, variant A...              -3.587627
# NC_004105.1 Ectromelia virus, complete genome                   -1.041632
# NC_003310.1 Monkeypox virus Zaire-96-I-16, comp...              -1.015272
# NC_035469.1 NY_014 poxvirus strain 2013, comple...              -0.173102
# NC_000898.1 Human herpesvirus 6B, complete genome               -2.483095
# NC_012783.2 Cercopithecine herpesvirus 5 strain...              -4.346644
# NC_006998.1 Vaccinia virus, complete genome                     -0.272825
# NC_003391.1 Camelpox virus, complete genome                     -2.109328
# NC_001611.1 Variola virus, complete genome                      -2.695336
# NC_002642.1 Yaba-like disease virus, complete g...              -1.699639
# NC_001716.2 Human herpesvirus 7, complete genome               -13.934627
# NC_001798.2 Human herpesvirus 2 strain HG52, co...               0.364238
# NC_007653.1 Papiine herpesvirus 2, complete genome               2.291407
# NC_003663.2 Cowpox virus, complete genome                       -1.067401
# NC_004812.1 Macacine herpesvirus 1, complete ge...               1.277175
# NC_013804.1 Pseudocowpox virus, complete genome                  0.300067
# NC_009333.1 Human herpesvirus 8 strain GK18, co...              -9.189681
# NC_001348.1 Human herpesvirus 3, complete genome                -3.366054
# NC_003266.2 Human adenovirus E, complete genome                 -5.992594
# NC_001454.1 Human adenovirus F, complete genome                 -5.673826
# NC_005337.1 Bovine papular stomatitis virus, co...              -0.262650
# NC_005336.1 Orf virus, complete genome                          -2.022642
# NC_011203.1 Human adenovirus B1, complete genome                -6.448724
# NC_001731.1 Molluscum contagiosum virus subtype...              -0.062886
# NC_003494.1 Infectious spleen and kidney necros...              -2.826042
# NC_001608.3 Marburg marburgvirus isolate Marbur...              -8.708710
# NC_001806.2 Human herpesvirus 1 strain 17, comp...               1.530172
# NC_011202.1 Human adenovirus B2, complete genome                -3.255039
# NC_001405.1 Human adenovirus C, complete genome                 -7.106609
# NC_017825.1 Chimpanzee adenovirus Y25, complete...              -7.795445
# NC_001460.1 Human adenovirus A, complete genome                 -4.965843
# NC_012959.1 Human adenovirus 54, complete genome                -7.283546
# NC_002728.1 Nipah virus, complete genome                       -11.818726
# NC_006879.1 Simian adenovirus 1, complete genome                -6.381060
#
#                                                     Crosscorrelation Max  \
# NC_004718.3 SARS coronavirus, complete genome                    13138.0
# NC_038294.1 Betacoronavirus England 1, complete...                3403.0
# NC_019843.3 Middle East respiratory syndrome co...                3400.0
# NC_003045.1 Bovine coronavirus, complete genome                   2190.0
# NC_006577.2 Human coronavirus HKU1, complete ge...                2148.0
# NC_001451.1 Avian infectious bronchitis virus, ...                2097.0
# NC_006213.1 Human coronavirus OC43 strain ATCC ...                1988.0
# NC_002645.1 Human coronavirus 229E, complete ge...                1984.0
# NC_005831.2 Human Coronavirus NL63, complete ge...                1845.0
# NC_028752.1 Camel alphacoronavirus isolate came...                1715.0
# NC_010800.1 Turkey coronavirus, complete genome                   1623.0
# NC_007447.1 Breda virus, complete genome                           890.0
# NC_007605.1 Human gammaherpesvirus 4, complete ...                 698.0
# NC_027016.1 Papio ursinus cytomegalovirus isola...                 675.0
# NC_006273.2 Human herpesvirus 5 strain Merlin, ...                      265548.0
# NC_009334.1 Human herpesvirus 4, complete genome                        202666.0
# NC_001664.4 Human betaherpesvirus 6A, variant A...                      189280.0
# NC_004105.1 Ectromelia virus, complete genome                           239673.0
# NC_003310.1 Monkeypox virus Zaire-96-I-16, comp...                      226760.0
# NC_035469.1 NY_014 poxvirus strain 2013, comple...                      230125.0
# NC_000898.1 Human herpesvirus 6B, complete genome                       192016.0
# NC_012783.2 Cercopithecine herpesvirus 5 strain...                      256107.0
# NC_006998.1 Vaccinia virus, complete genome                             224613.0
# NC_003391.1 Camelpox virus, complete genome                             235621.0
# NC_001611.1 Variola virus, complete genome                              215480.0
# NC_002642.1 Yaba-like disease virus, complete g...                      174477.0
# NC_001716.2 Human herpesvirus 7, complete genome                        182982.0
# NC_001798.2 Human herpesvirus 2 strain HG52, co...                      184577.0
# NC_007653.1 Papiine herpesvirus 2, complete genome                      186389.0
# NC_003663.2 Cowpox virus, complete genome                               254401.0
# NC_004812.1 Macacine herpesvirus 1, complete ge...                      186691.0
# NC_013804.1 Pseudocowpox virus, complete genome                         175191.0
# NC_009333.1 Human herpesvirus 8 strain GK18, co...                      167871.0
# NC_001348.1 Human herpesvirus 3, complete genome                        154786.0
# NC_003266.2 Human adenovirus E, complete genome                          65896.0
# NC_001454.1 Human adenovirus F, complete genome                          64116.0
# NC_005337.1 Bovine papular stomatitis virus, co...                      164333.0
# NC_005336.1 Orf virus, complete genome                                  169864.0
# NC_011203.1 Human adenovirus B1, complete genome                         65245.0
# NC_001731.1 Molluscum contagiosum virus subtype...                      220191.0
# NC_003494.1 Infectious spleen and kidney necros...                      141264.0
# NC_001608.3 Marburg marburgvirus isolate Marbur...                       49013.0
# NC_001806.2 Human herpesvirus 1 strain 17, comp...                      182124.0
# NC_011202.1 Human adenovirus B2, complete genome                         64696.0
# NC_001405.1 Human adenovirus C, complete genome                          65839.0
# NC_017825.1 Chimpanzee adenovirus Y25, complete...                       66613.0
# NC_001460.1 Human adenovirus A, complete genome                          64027.0
# NC_012959.1 Human adenovirus 54, complete genome                         64822.0
# NC_002728.1 Nipah virus, complete genome                                 48148.0
# NC_006879.1 Simian adenovirus 1, complete genome                         64352.0

# %% [markdown]
# ## Network

# %%
adj_dict={}
xcorr_max_thr = 700.

for v1,g1 in virus_dict.items():
    adj_dict[v1] = {}
    for v2,g2 in virus_dict.items():
        if v1!=v2:
            xcorr = np.correlate(g1,g2, "full")
            x = np.max(np.absolute(xcorr))
            if (x > xcorr_max_thr):
                adj_dict[v1][v2]=x
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-69589ce3a26b> in <module>
#       6     for v2,g2 in virus_dict.items():
#       7         if v1!=v2:
# ----> 8             xcorr = np.correlate(g1,g2, "full")
#       9             x = np.max(np.absolute(xcorr))
#      10             if (x > xcorr_max_thr):
#
# <__array_function__ internals> in correlate(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py in correlate(a, v, mode)
#     710     """
#     711     mode = _mode_from_name(mode)
# --> 712     return multiarray.correlate2(a, v, mode)
#     713
#     714
#
# KeyboardInterrupt:
